# %%
import tweepy
import matplotlib.pyplot as plt
from  textblob import TextBlob 
import time

# %%
# all 4 authentication keys to access twitter API
# to connect as OAth handler or jump serever / revers proxy server
consumer_key = "8AO6OU5ubyi4XO47b1C7Sjdlz"
consumer_sec = "FS1usPrfPolvjLXbwGka5N8TWkOZhUsdxGmmTwuO016koesUSt"

# from proxy server we need to connect
access_token = "1151573806680592384-OUFeUtpsRFZM6jQxl1AG99NEjlY0Kt"
access_token_sec = "KKHmkHkDGVaDof8XK4fKKI52DmNl4vZlaXnx85WRfd4Lr"

# %%
# tweepy explore
dir(tweepy)

# %%
# connected to jump server of twitter
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
# now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_token_sec)

# %%
# now we can connect to API storge server of twitter
api_connect=tweepy.API(auth)

# %%
# now you can search any topic on twitter
tweet_data=api_connect.search('Sidharth Shukla',count=100)

# %%
pos=0
neg=0
neu=0

# printing line by line
for tweet in tweet_data:
   #print(tweet.text)
   analysis=TextBlob(tweet.text) # here it will apply NLP\
   print(analysis.sentiment)
   # now checking polarity only
   if analysis.sentiment.polarity > 0:
      print("posative")
      pos=pos+1
   elif analysis.sentiment.polarity == 0 :
      print("Neutral")
      neu=neu+1
   else :
      print("Negative")
      neg=neg+1
      

# ploting graphs
plt.xlabel("tags")
plt.ylabel("polarity")
#plt.bar(['pos','neg','neu'],[pos,neg,neu])
plt.pie([pos,neg,neu],labels=['pos','neg','neu'],autopct="%1.1f%%")
plt.show()
# Out:
# Sentiment(polarity=0.5, subjectivity=0.625)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.4, subjectivity=0.9)
# posative
# Sentiment(polarity=0.7375, subjectivity=0.8)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.13333333333333333, subjectivity=0.5666666666666668)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.6, subjectivity=0.35833333333333334)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.2222222222222222)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.25)
# Neutral
# Sentiment(polarity=0.13333333333333333, subjectivity=0.3)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.037500000000000006, subjectivity=0.2375)
# posative
# Sentiment(polarity=-0.2916666666666667, subjectivity=0.5416666666666666)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.5)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.7375, subjectivity=0.8)
# posative
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.15, subjectivity=0.175)
# posative
# Sentiment(polarity=0.0, subjectivity=1.0)
# Neutral
# Sentiment(polarity=0.9, subjectivity=0.9)
# posative
# Sentiment(polarity=0.25, subjectivity=0.2833333333333333)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.25)
# Neutral
# Sentiment(polarity=0.625, subjectivity=0.4)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.9, subjectivity=0.9)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.325, subjectivity=0.625)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.6)
# posative
# Sentiment(polarity=0.5625, subjectivity=0.55)
# posative
# Sentiment(polarity=0.15, subjectivity=0.175)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5859375, subjectivity=0.1)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.4285714285714286, subjectivity=0.5357142857142857)
# posative
# Sentiment(polarity=-0.4, subjectivity=0.7)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.6)
# posative
# Sentiment(polarity=0.45, subjectivity=0.7000000000000001)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.9)
# posative
# Sentiment(polarity=0.15, subjectivity=0.175)
# posative
# Sentiment(polarity=0.4285714285714286, subjectivity=0.5357142857142857)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.35000000000000003, subjectivity=0.7666666666666666)
# posative
# Sentiment(polarity=0.625, subjectivity=0.4)
# posative
# Sentiment(polarity=0.6, subjectivity=0.9)
# posative
# Sentiment(polarity=0.5, subjectivity=1.0)
# posative
# Sentiment(polarity=0.625, subjectivity=0.4)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.625)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.75, subjectivity=0.44999999999999996)
# posative
# Sentiment(polarity=0.2333333333333333, subjectivity=0.5666666666666667)
# posative
# Sentiment(polarity=0.22499999999999998, subjectivity=0.7)
# posative
# Sentiment(polarity=0.7, subjectivity=0.9)
# posative
# Sentiment(polarity=0.22499999999999998, subjectivity=0.7)
# posative
# Sentiment(polarity=0.22499999999999998, subjectivity=0.7)
# posative
# Sentiment(polarity=0.7, subjectivity=0.8)
# posative
# Sentiment(polarity=0.75, subjectivity=0.44999999999999996)
# posative
# Sentiment(polarity=0.13333333333333333, subjectivity=0.3)
# posative
# Sentiment(polarity=0.7375, subjectivity=0.8)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
